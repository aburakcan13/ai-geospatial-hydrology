# %% [markdown]
# # Chapter 1: Ingesting Sentinel-2 and ECMWF ERA5 Climate Data
# **AI-Driven Geospatial Hydrology (Springer Nature - Studies in Big Data)**
#
# This notebook demonstrates downloading ERA5 meteorological grids and synchronizing precipitation sequences with surface water dynamics.

# %%
from src.data_loaders.era5_loader import ERA5ClimateLoader

# Koordinatlar: Mersin/Seyhan Havzası [Kuzey, Batı, Güney, Doğu]
bbox = (37.5, 34.5, 36.5, 35.5)

loader = ERA5ClimateLoader(output_dir='../data/sample_inputs')
print('ERA5 Climate Loader initialized successfully.')

# %% [markdown]
# # Chapter 3: Boundary-Aware Residual U-Net for Surface Water Segmentation
# **AI-Driven Geospatial Hydrology (Springer Nature - Studies in Big Data)**
#
# This notebook demonstrates end-to-end multi-spectral patch ingestion, boundary-loss training, and shoreline delineation on Sentinel-2 imagery.

# %%
import torch
import numpy as np
from src.models.unet_boundary import BoundaryAwareResUNet
from src.visualization.map_overlays import plot_water_extraction_comparison

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BoundaryAwareResUNet(in_channels=8, num_classes=1).to(device)
print(f'Model initialized on device: {device}')
